# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import warnings
import os
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from itertools import repeat
from time import perf_counter
from sklearn.metrics import *
from imblearn.over_sampling import SMOTE
import lightgbm as lgb
from matplotlib import pyplot as plt
from lightgbm import plot_importance
from lightgbm import plot_tree
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
pd.set_option('display.max_columns', None)

# %%
file_name = 'final_data_v2.csv'
file_path = os.getcwd()+'/drive/MyDrive/Colab Notebooks/' 
df = pd.read_csv(file_path+file_name, encoding='utf-8')
df.rename(columns={'category_id_1':'category1'}, inplace=True)
df.head(3)
# Out:
#                  imp_id  content_id                 server_time_kst_x  \
# 0  9919612e44382421285c   162261579  2021-09-01 00:01:42.466000+09:00
# 1  9919612e444924217d59   145430389  2021-09-01 00:01:42.466000+09:00
# 2  97f9612e444d18489e0e    98827336  2021-09-01 00:01:40.339000+09:00
#
#    imp_hour  bid_price_x  click_label user_gender  user_age_group  user_age  \
# 0         0           55            0           F               1        16
# 1         0           70            0           F               2        26
# 2         0           50            0           F               5        53
#
#    user_following_cnt  user_pay_count  user_parcel_post_count  \
# 0                   3               0                       0
# 1                   0               0                       0
# 2                   0               0                       0
#
#    user_transfer_count  user_chat_count  \
# 0                    0                2
# 1                    0                0
# 2                    0                0
#
#                                       name  \
# 0        Z플립 5G  256GB  [그레이]  48082  (S급)
# 1      최저가60 무선청소기 기펠상위모델 국내브랜드 셀프스텐드 정품무배
# 2  정품 원터치텐트 낚시텐트 자외선차단텐트 방수텐트 캠핑텐트 간편 자동텐트
#
#                                          keyword     price  flag_used  \
# 0            Z플립5G,제트플립,제트플립5G,갤럭시Z플립5G,Z플립5G그레이  580000.0        1.0
# 1                          기펠청소기,무선청소기,코드제로,에어슬림  135000.0        2.0
# 2  원터치텐트간편텐트,낚시텐트등산텐트,자외선차단방수텐트,자동텐트감성캠핑,캠핑용품그늘막   26000.0        2.0
#
#    category1  emergency_cnt  comment_cnt  ad_interest  ad_pfavcnt  \
# 0        600            0.0          0.0        120.0         4.0
# 1        600            0.0          3.0       5385.0       153.0
# 2        700            0.0         12.0      29950.0       759.0
#
#    adver_favorite_count  adver_grade  adver_item_count  adver_interest  \
# 0                2063.0       7539.0             784.0          3424.0
# 1                 799.0       5520.0             433.0         16794.0
# 2                2120.0       3252.0            2053.0         32794.0
#
#    adver_review_count  adver_comment_count  adver_pay_count  \
# 0               755.0                392.0            677.0
# 1               570.0                250.0            942.0
# 2               351.0                441.0            166.0
#
#    adver_parcel_post_count  adver_transfer_count  adver_chat_count  \
# 0                      0.0                   5.0             236.0
# 1                      0.0                  57.0              11.0
# 2                      0.0                  16.0               3.0
#
#        m_time                                    content_img_url
# 0  1629443915  https://media.bunjang.co.kr/product/162261579_...
# 1  1629943339  https://media.bunjang.co.kr/product/145430389_...
# 2  1627289231  https://media.bunjang.co.kr/product/98827336_1...

# %%
cols = {'obj': [],
        'cat': [],
       'cont': []
        }

def data_split():
    file_name = 'final_data_v2.csv'
    file_path = os.getcwd()+'/drive/MyDrive/Colab Notebooks/' #[:-16]는 본인 경로에 맞게 있어도 되고 없어도 됨.
    df = pd.read_csv(file_path+file_name, encoding='utf-8')
    df.rename(columns={'category_id_1':'category1'}, inplace=True)

    # 데이터 유형별 분류하기
    for dt_idx, dt_val in zip(df.dtypes.index, df.dtypes.values):
        if dt_val == 'object':
            if ('id' in dt_idx) | ('time' in dt_idx) | ('name' in dt_idx) | ('keyword' in dt_idx) |('url' in dt_idx):
                df.drop(columns = dt_idx, axis=1, inplace=True)
            else:
                cols['obj'].append(dt_idx)

        else:
            if ('id' in dt_idx) | ('time' in dt_idx):
                df.drop(columns = dt_idx, axis=1, inplace=True)
            else:
                if len(df[dt_idx].value_counts()) <= 30: #연속형 데이터 중 30개 내의 범주로 나눌 수 있는 데이터 = category로 구분.
                    cols['cat'].append(dt_idx)
                else:
                    if ('hour' in dt_idx) | ('group' in dt_idx):
                        pass
                    else:
                        cols['cont'].append(dt_idx) 

    return cols

def reorganization(df):
  data = pd.DataFrame()
  cols = data_split()
  for k, v in cols.items():
    if k == 'obj':
      data = pd.concat([data, df[v]], axis=1)
    elif k == 'cont':
      data = pd.concat([data, df[v]], axis=1)
    else:
      data = pd.concat([data, df[v]], axis=1)

  return data

# %%
data = reorganization(df)
data.columns
# Out:
# Index(['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used',
#        'category1', 'emergency_cnt', 'user_age', 'user_following_cnt',
#        'user_pay_count', 'user_parcel_post_count', 'user_transfer_count',
#        'user_chat_count', 'price', 'comment_cnt', 'ad_interest', 'ad_pfavcnt',
#        'adver_favorite_count', 'adver_grade', 'adver_item_count',
#        'adver_interest', 'adver_review_count', 'adver_comment_count',
#        'adver_pay_count', 'adver_parcel_post_count', 'adver_transfer_count',
#        'adver_chat_count'],
#       dtype='object')

# %%
data.head(3)
# Out:
#   user_gender  imp_hour  click_label  user_age_group  flag_used  category1  \
# 0           F         0            0               1        1.0        600
# 1           F         0            0               2        2.0        600
# 2           F         0            0               5        2.0        700
#
#    emergency_cnt  user_age  user_following_cnt  user_pay_count  \
# 0            0.0        16                   3               0
# 1            0.0        26                   0               0
# 2            0.0        53                   0               0
#
#    user_parcel_post_count  user_transfer_count  user_chat_count     price  \
# 0                       0                    0                2  580000.0
# 1                       0                    0                0  135000.0
# 2                       0                    0                0   26000.0
#
#    comment_cnt  ad_interest  ad_pfavcnt  adver_favorite_count  adver_grade  \
# 0          0.0        120.0         4.0                2063.0       7539.0
# 1          3.0       5385.0       153.0                 799.0       5520.0
# 2         12.0      29950.0       759.0                2120.0       3252.0
#
#    adver_item_count  adver_interest  adver_review_count  adver_comment_count  \
# 0             784.0          3424.0               755.0                392.0
# 1             433.0         16794.0               570.0                250.0
# 2            2053.0         32794.0               351.0                441.0
#
#    adver_pay_count  adver_parcel_post_count  adver_transfer_count  \
# 0            677.0                      0.0                   5.0
# 1            942.0                      0.0                  57.0
# 2            166.0                      0.0                  16.0
#
#    adver_chat_count
# 0             236.0
# 1              11.0
# 2               3.0

# %%
def preprocessing(df):
    # 데이터 유형별 분류하기
    modified_df = pd.DataFrame()

    for i, c in enumerate(df.columns): 
        if (c in cols['obj']) | (c in cols['cat']): 
          if 'click' in c:    # click_label 컬럼 = y 변수로 사용 (그대로 두기)
                modified_df = pd.concat([modified_df, df[c]], axis=1)
          else:
            dummied_data = LabelEncoder().fit_transform(df[[c]])
            dummied_data = pd.DataFrame(dummied_data, columns = [c])
            modified_df = pd.concat([modified_df, dummied_data], axis=1)

        else:
            scaled_num_data = RobustScaler().fit_transform(df[[c]])
            scaled_num_data = pd.DataFrame(scaled_num_data, columns = [c])
            modified_df = pd.concat([modified_df,scaled_num_data], axis=1)

    print('---- Data info ----')
    print(f'Modified DF columns: {modified_df.columns.to_list()}')
    print(f'# of Modified DF columns: {modified_df.shape[1]}')
    print(f'DataFrame has no null?', end = ' ')
    if df.isnull().sum().count() == df.shape[1]:
      print('Yes')
    else:
      print('No')
    return modified_df

# %%
df = preprocessing(data)
df.head(3)
# Out:
# ---- Data info ----
# Modified DF columns: ['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used', 'category1', 'emergency_cnt', 'user_age', 'user_following_cnt', 'user_pay_count', 'user_parcel_post_count', 'user_transfer_count', 'user_chat_count', 'price', 'comment_cnt', 'ad_interest', 'ad_pfavcnt', 'adver_favorite_count', 'adver_grade', 'adver_item_count', 'adver_interest', 'adver_review_count', 'adver_comment_count', 'adver_pay_count', 'adver_parcel_post_count', 'adver_transfer_count', 'adver_chat_count']
# # of Modified DF columns: 27
# DataFrame has no null? Yes
#    user_gender  imp_hour  click_label  user_age_group  flag_used  category1  \
# 0            0         0            0               0          0         10
# 1            0         0            0               1          1         10
# 2            0         0            0               4          1         11
#
#    emergency_cnt  user_age  user_following_cnt  user_pay_count  \
# 0              0 -0.904762                 0.4             0.0
# 1              0 -0.428571                -0.2             0.0
# 2              0  0.857143                -0.2             0.0
#
#    user_parcel_post_count  user_transfer_count  user_chat_count     price  \
# 0                     0.0                  0.0              2.0  0.442373
# 1                     0.0                  0.0              0.0 -0.311864
# 2                     0.0                  0.0              0.0 -0.496610
#
#    comment_cnt  ad_interest  ad_pfavcnt  adver_favorite_count  adver_grade  \
# 0          0.0    -0.138204   -0.190476              0.541252     0.731446
# 1          3.0     0.607335    1.228571             -0.086978     0.442728
# 2         12.0     4.085811    7.000000              0.569583     0.118404
#
#    adver_item_count  adver_interest  adver_review_count  adver_comment_count  \
# 0          0.742301       -0.030500            0.695833             0.246594
# 1          0.173420        0.339880            0.438889             0.053134
# 2          2.799028        0.783118            0.134722             0.313351
#
#    adver_pay_count  adver_parcel_post_count  adver_transfer_count  \
# 0         1.209776                      0.0              0.714286
# 1         1.749491                      0.0              8.142857
# 2         0.169043                      0.0              2.285714
#
#    adver_chat_count
# 0         17.769231
# 1          0.461538
# 2         -0.153846

# %%
X = df
y = df['click_label']

print(f"X features' name (10): {X.columns.to_list()[:10]}")
print(f"y feature's name: {y.name}")
print()

## create train and test datasets (7:3 ratio)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2022, stratify = y) #y 비율에 따른 층화추출 및 데이터를 7:3의 비율로 나누기

print(f"# of train_data's rows: {X_train.shape[0]} \n# of test_data's rows: {X_test.shape[0]}")
print()
print(f'train:test ratio = {round(X_train.shape[0]/(X_train.shape[0]+ X_test.shape[0]),2)}:{round(X_test.shape[0]/(X_train.shape[0]+ X_test.shape[0]), 2)}')

oversample = SMOTE(random_state=2022) # 불균형 데이터 셋인 번개장터 데이터 셋 불균형 문제 완화
X_train, y_train = oversample.fit_resample(X_train, y_train)

print("data's shape (x -> y & train -> test): ", (X_train.shape, y_train.shape, X_test.shape, y_train.shape))
print()

# ## create train and validation datasets (8:2 ratio)
# x_train, x_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state = 2022, stratify = y_train)

# print(f"# of train_data's rows: {x_train.shape[0]} \n# of validation_data's rows: {x_val.shape[0]}")
# print()
# print(f'train:test ratio = {round(x_train.shape[0]/(x_train.shape[0]+ x_val.shape[0]),2)}:{round(x_val.shape[0]/(x_train.shape[0]+ x_val.shape[0]), 2)}')
# print("data's shape (x -> y & train -> test): ", (x_train.shape, y_train.shape, x_val.shape, y_train.shape))
# print()
# Out:
# X features' name (10): ['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used', 'category1', 'emergency_cnt', 'user_age', 'user_following_cnt', 'user_pay_count']
# y feature's name: click_label
#
# # of train_data's rows: 589724
# # of test_data's rows: 252739
#
# train:test ratio = 0.7:0.3
# data's shape (x -> y & train -> test):  ((1144850, 27), (1144850,), (252739, 27), (1144850,))

# %%
lgb_model = lgb.LGBMClassifier(random_state=2022, boosting_type = 'gbdt', n_estimators = 200)
lgb_model = lgb_model.fit(X_train, y_train, early_stopping_rounds=10) #eval_metric="logloss", eval_set = [(X_test, y_test)])
lgb_model
# Out:
# [1]	valid_0's binary_logloss: 0.598139	valid_0's binary_logloss: 0.598139
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.520329	valid_0's binary_logloss: 0.520329
# [3]	valid_0's binary_logloss: 0.455444	valid_0's binary_logloss: 0.455444
# [4]	valid_0's binary_logloss: 0.400598	valid_0's binary_logloss: 0.400598
# [5]	valid_0's binary_logloss: 0.353747	valid_0's binary_logloss: 0.353747
# [6]	valid_0's binary_logloss: 0.313388	valid_0's binary_logloss: 0.313388
# [7]	valid_0's binary_logloss: 0.278384	valid_0's binary_logloss: 0.278384
# [8]	valid_0's binary_logloss: 0.247853	valid_0's binary_logloss: 0.247853
# [9]	valid_0's binary_logloss: 0.221099	valid_0's binary_logloss: 0.221099
# [10]	valid_0's binary_logloss: 0.19756	valid_0's binary_logloss: 0.19756
# [11]	valid_0's binary_logloss: 0.176781	valid_0's binary_logloss: 0.176781
# [12]	valid_0's binary_logloss: 0.158385	valid_0's binary_logloss: 0.158385
# [13]	valid_0's binary_logloss: 0.142058	valid_0's binary_logloss: 0.142058
# [14]	valid_0's binary_logloss: 0.127536	valid_0's binary_logloss: 0.127536
# [15]	valid_0's binary_logloss: 0.114594	valid_0's binary_logloss: 0.114594
# [16]	valid_0's binary_logloss: 0.103042	valid_0's binary_logloss: 0.103042
# [17]	valid_0's binary_logloss: 0.0927149	valid_0's binary_logloss: 0.0927149
# [18]	valid_0's binary_logloss: 0.0834714	valid_0's binary_logloss: 0.0834714
# [19]	valid_0's binary_logloss: 0.0751883	valid_0's binary_logloss: 0.0751883
# [20]	valid_0's binary_logloss: 0.0677582	valid_0's binary_logloss: 0.0677582
# [21]	valid_0's binary_logloss: 0.0610874	valid_0's binary_logloss: 0.0610874
# [22]	valid_0's binary_logloss: 0.0550936	valid_0's binary_logloss: 0.0550936
# [23]	valid_0's binary_logloss: 0.0497041	valid_0's binary_logloss: 0.0497041
# [24]	valid_0's binary_logloss: 0.044855	valid_0's binary_logloss: 0.044855
# [25]	valid_0's binary_logloss: 0.0404896	valid_0's binary_logloss: 0.0404896
# [26]	valid_0's binary_logloss: 0.0365577	valid_0's binary_logloss: 0.0365577
# [27]	valid_0's binary_logloss: 0.0330146	valid_0's binary_logloss: 0.0330146
# [28]	valid_0's binary_logloss: 0.0298206	valid_0's binary_logloss: 0.0298206
# [29]	valid_0's binary_logloss: 0.0269402	valid_0's binary_logloss: 0.0269402
# [30]	valid_0's binary_logloss: 0.0243418	valid_0's binary_logloss: 0.0243418
# [31]	valid_0's binary_logloss: 0.021997	valid_0's binary_logloss: 0.021997
# [32]	valid_0's binary_logloss: 0.0198806	valid_0's binary_logloss: 0.0198806
# [33]	valid_0's binary_logloss: 0.0179698	valid_0's binary_logloss: 0.0179698
# [34]	valid_0's binary_logloss: 0.0162444	valid_0's binary_logloss: 0.0162444
# [35]	valid_0's binary_logloss: 0.0146859	valid_0's binary_logloss: 0.0146859
# [36]	valid_0's binary_logloss: 0.0132781	valid_0's binary_logloss: 0.0132781
# [37]	valid_0's binary_logloss: 0.0120061	valid_0's binary_logloss: 0.0120061
# [38]	valid_0's binary_logloss: 0.0108567	valid_0's binary_logloss: 0.0108567
# [39]	valid_0's binary_logloss: 0.00981796	valid_0's binary_logloss: 0.00981796
# [40]	valid_0's binary_logloss: 0.00887907	valid_0's binary_logloss: 0.00887907
# [41]	valid_0's binary_logloss: 0.00803037	valid_0's binary_logloss: 0.00803037
# [42]	valid_0's binary_logloss: 0.00726311	valid_0's binary_logloss: 0.00726311
# [43]	valid_0's binary_logloss: 0.00656942	valid_0's binary_logloss: 0.00656942
# [44]	valid_0's binary_logloss: 0.00594221	valid_0's binary_logloss: 0.00594221
# [45]	valid_0's binary_logloss: 0.00537506	valid_0's binary_logloss: 0.00537506
# [46]	valid_0's binary_logloss: 0.00486218	valid_0's binary_logloss: 0.00486218
# [47]	valid_0's binary_logloss: 0.00439836	valid_0's binary_logloss: 0.00439836
# [48]	valid_0's binary_logloss: 0.00397888	valid_0's binary_logloss: 0.00397888
# [49]	valid_0's binary_logloss: 0.00359949	valid_0's binary_logloss: 0.00359949
# [50]	valid_0's binary_logloss: 0.00325634	valid_0's binary_logloss: 0.00325634
# [51]	valid_0's binary_logloss: 0.00294595	valid_0's binary_logloss: 0.00294595
# [52]	valid_0's binary_logloss: 0.00266519	valid_0's binary_logloss: 0.00266519
# [53]	valid_0's binary_logloss: 0.00241123	valid_0's binary_logloss: 0.00241123
# [54]	valid_0's binary_logloss: 0.0021815	valid_0's binary_logloss: 0.0021815
# [55]	valid_0's binary_logloss: 0.00197367	valid_0's binary_logloss: 0.00197367
# [56]	valid_0's binary_logloss: 0.00178567	valid_0's binary_logloss: 0.00178567
# [57]	valid_0's binary_logloss: 0.00161559	valid_0's binary_logloss: 0.00161559
# [58]	valid_0's binary_logloss: 0.00146172	valid_0's binary_logloss: 0.00146172
# [59]	valid_0's binary_logloss: 0.00132252	valid_0's binary_logloss: 0.00132252
# [60]	valid_0's binary_logloss: 0.00119658	valid_0's binary_logloss: 0.00119658
# [61]	valid_0's binary_logloss: 0.00108264	valid_0's binary_logloss: 0.00108264
# [62]	valid_0's binary_logloss: 0.000979561	valid_0's binary_logloss: 0.000979561
# [63]	valid_0's binary_logloss: 0.000886298	valid_0's binary_logloss: 0.000886298
# [64]	valid_0's binary_logloss: 0.000801918	valid_0's binary_logloss: 0.000801918
# [65]	valid_0's binary_logloss: 0.000725575	valid_0's binary_logloss: 0.000725575
# [66]	valid_0's binary_logloss: 0.000656502	valid_0's binary_logloss: 0.000656502
# [67]	valid_0's binary_logloss: 0.000594007	valid_0's binary_logloss: 0.000594007
# [68]	valid_0's binary_logloss: 0.000537463	valid_0's binary_logloss: 0.000537463
# [69]	valid_0's binary_logloss: 0.000486303	valid_0's binary_logloss: 0.000486303
# [70]	valid_0's binary_logloss: 0.000440014	valid_0's binary_logloss: 0.000440014
# [71]	valid_0's binary_logloss: 0.000398132	valid_0's binary_logloss: 0.000398132
# [72]	valid_0's binary_logloss: 0.000360237	valid_0's binary_logloss: 0.000360237
# [73]	valid_0's binary_logloss: 0.00032595	valid_0's binary_logloss: 0.00032595
# [74]	valid_0's binary_logloss: 0.000294927	valid_0's binary_logloss: 0.000294927
# [75]	valid_0's binary_logloss: 0.000266857	valid_0's binary_logloss: 0.000266857
# [76]	valid_0's binary_logloss: 0.000241458	valid_0's binary_logloss: 0.000241458
# [77]	valid_0's binary_logloss: 0.000218478	valid_0's binary_logloss: 0.000218478
# [78]	valid_0's binary_logloss: 0.000197685	valid_0's binary_logloss: 0.000197685
# [79]	valid_0's binary_logloss: 0.000178871	valid_0's binary_logloss: 0.000178871
# [80]	valid_0's binary_logloss: 0.000161847	valid_0's binary_logloss: 0.000161847
# [81]	valid_0's binary_logloss: 0.000146444	valid_0's binary_logloss: 0.000146444
# [82]	valid_0's binary_logloss: 0.000132507	valid_0's binary_logloss: 0.000132507
# [83]	valid_0's binary_logloss: 0.000119897	valid_0's binary_logloss: 0.000119897
# [84]	valid_0's binary_logloss: 0.000108486	valid_0's binary_logloss: 0.000108486
# [85]	valid_0's binary_logloss: 9.81619e-05	valid_0's binary_logloss: 9.81619e-05
# [86]	valid_0's binary_logloss: 8.88201e-05	valid_0's binary_logloss: 8.88201e-05
# [87]	valid_0's binary_logloss: 8.03674e-05	valid_0's binary_logloss: 8.03674e-05
# [88]	valid_0's binary_logloss: 7.27191e-05	valid_0's binary_logloss: 7.27191e-05
# [89]	valid_0's binary_logloss: 6.57987e-05	valid_0's binary_logloss: 6.57987e-05
# [90]	valid_0's binary_logloss: 5.9537e-05	valid_0's binary_logloss: 5.9537e-05
# [91]	valid_0's binary_logloss: 5.38711e-05	valid_0's binary_logloss: 5.38711e-05
# [92]	valid_0's binary_logloss: 4.87445e-05	valid_0's binary_logloss: 4.87445e-05
# [93]	valid_0's binary_logloss: 4.41057e-05	valid_0's binary_logloss: 4.41057e-05
# [94]	valid_0's binary_logloss: 3.99084e-05	valid_0's binary_logloss: 3.99084e-05
# [95]	valid_0's binary_logloss: 3.61105e-05	valid_0's binary_logloss: 3.61105e-05
# [96]	valid_0's binary_logloss: 3.26741e-05	valid_0's binary_logloss: 3.26741e-05
# [97]	valid_0's binary_logloss: 2.95647e-05	valid_0's binary_logloss: 2.95647e-05
# [98]	valid_0's binary_logloss: 2.67512e-05	valid_0's binary_logloss: 2.67512e-05
# [99]	valid_0's binary_logloss: 2.42055e-05	valid_0's binary_logloss: 2.42055e-05
# [100]	valid_0's binary_logloss: 2.1902e-05	valid_0's binary_logloss: 2.1902e-05
# [101]	valid_0's binary_logloss: 1.98177e-05	valid_0's binary_logloss: 1.98177e-05
# [102]	valid_0's binary_logloss: 1.79318e-05	valid_0's binary_logloss: 1.79318e-05
# [103]	valid_0's binary_logloss: 1.62253e-05	valid_0's binary_logloss: 1.62253e-05
# [104]	valid_0's binary_logloss: 1.46813e-05	valid_0's binary_logloss: 1.46813e-05
# [105]	valid_0's binary_logloss: 1.32842e-05	valid_0's binary_logloss: 1.32842e-05
# [106]	valid_0's binary_logloss: 1.202e-05	valid_0's binary_logloss: 1.202e-05
# [107]	valid_0's binary_logloss: 1.08761e-05	valid_0's binary_logloss: 1.08761e-05
# [108]	valid_0's binary_logloss: 9.84112e-06	valid_0's binary_logloss: 9.84112e-06
# [109]	valid_0's binary_logloss: 8.90461e-06	valid_0's binary_logloss: 8.90461e-06
# [110]	valid_0's binary_logloss: 8.05722e-06	valid_0's binary_logloss: 8.05722e-06
# [111]	valid_0's binary_logloss: 7.29047e-06	valid_0's binary_logloss: 7.29047e-06
# [112]	valid_0's binary_logloss: 6.59669e-06	valid_0's binary_logloss: 6.59669e-06
# [113]	valid_0's binary_logloss: 5.96893e-06	valid_0's binary_logloss: 5.96893e-06
# [114]	valid_0's binary_logloss: 5.40091e-06	valid_0's binary_logloss: 5.40091e-06
# [115]	valid_0's binary_logloss: 4.88694e-06	valid_0's binary_logloss: 4.88694e-06
# [116]	valid_0's binary_logloss: 4.42189e-06	valid_0's binary_logloss: 4.42189e-06
# [117]	valid_0's binary_logloss: 4.00109e-06	valid_0's binary_logloss: 4.00109e-06
# [118]	valid_0's binary_logloss: 3.62033e-06	valid_0's binary_logloss: 3.62033e-06
# [119]	valid_0's binary_logloss: 3.27581e-06	valid_0's binary_logloss: 3.27581e-06
# [120]	valid_0's binary_logloss: 2.96408e-06	valid_0's binary_logloss: 2.96408e-06
# [121]	valid_0's binary_logloss: 2.68201e-06	valid_0's binary_logloss: 2.68201e-06
# [122]	valid_0's binary_logloss: 2.42678e-06	valid_0's binary_logloss: 2.42678e-06
# [123]	valid_0's binary_logloss: 2.19584e-06	valid_0's binary_logloss: 2.19584e-06
# [124]	valid_0's binary_logloss: 1.98688e-06	valid_0's binary_logloss: 1.98688e-06
# [125]	valid_0's binary_logloss: 1.7978e-06	valid_0's binary_logloss: 1.7978e-06
# [126]	valid_0's binary_logloss: 1.62672e-06	valid_0's binary_logloss: 1.62672e-06
# [127]	valid_0's binary_logloss: 1.47192e-06	valid_0's binary_logloss: 1.47192e-06
# [128]	valid_0's binary_logloss: 1.33185e-06	valid_0's binary_logloss: 1.33185e-06
# [129]	valid_0's binary_logloss: 1.2051e-06	valid_0's binary_logloss: 1.2051e-06
# [130]	valid_0's binary_logloss: 1.09042e-06	valid_0's binary_logloss: 1.09042e-06
# [131]	valid_0's binary_logloss: 9.86655e-07	valid_0's binary_logloss: 9.86655e-07
# [132]	valid_0's binary_logloss: 8.92762e-07	valid_0's binary_logloss: 8.92762e-07
# [133]	valid_0's binary_logloss: 8.07805e-07	valid_0's binary_logloss: 8.07805e-07
# [134]	valid_0's binary_logloss: 7.30932e-07	valid_0's binary_logloss: 7.30932e-07
# [135]	valid_0's binary_logloss: 6.61374e-07	valid_0's binary_logloss: 6.61374e-07
# [136]	valid_0's binary_logloss: 5.98436e-07	valid_0's binary_logloss: 5.98436e-07
# [137]	valid_0's binary_logloss: 5.41488e-07	valid_0's binary_logloss: 5.41488e-07
# [138]	valid_0's binary_logloss: 4.89958e-07	valid_0's binary_logloss: 4.89958e-07
# [139]	valid_0's binary_logloss: 4.43333e-07	valid_0's binary_logloss: 4.43333e-07
# [140]	valid_0's binary_logloss: 4.01144e-07	valid_0's binary_logloss: 4.01144e-07
# [141]	valid_0's binary_logloss: 3.6297e-07	valid_0's binary_logloss: 3.6297e-07
# [142]	valid_0's binary_logloss: 3.28429e-07	valid_0's binary_logloss: 3.28429e-07
# [143]	valid_0's binary_logloss: 2.97175e-07	valid_0's binary_logloss: 2.97175e-07
# [144]	valid_0's binary_logloss: 2.68895e-07	valid_0's binary_logloss: 2.68895e-07
# [145]	valid_0's binary_logloss: 2.43306e-07	valid_0's binary_logloss: 2.43306e-07
# [146]	valid_0's binary_logloss: 2.20152e-07	valid_0's binary_logloss: 2.20152e-07
# [147]	valid_0's binary_logloss: 1.99202e-07	valid_0's binary_logloss: 1.99202e-07
# [148]	valid_0's binary_logloss: 1.80246e-07	valid_0's binary_logloss: 1.80246e-07
# [149]	valid_0's binary_logloss: 1.63093e-07	valid_0's binary_logloss: 1.63093e-07
# [150]	valid_0's binary_logloss: 1.47573e-07	valid_0's binary_logloss: 1.47573e-07
# [151]	valid_0's binary_logloss: 1.33529e-07	valid_0's binary_logloss: 1.33529e-07
# [152]	valid_0's binary_logloss: 1.20822e-07	valid_0's binary_logloss: 1.20822e-07
# [153]	valid_0's binary_logloss: 1.09324e-07	valid_0's binary_logloss: 1.09324e-07
# [154]	valid_0's binary_logloss: 9.89208e-08	valid_0's binary_logloss: 9.89208e-08
# [155]	valid_0's binary_logloss: 8.95073e-08	valid_0's binary_logloss: 8.95073e-08
# [156]	valid_0's binary_logloss: 8.09895e-08	valid_0's binary_logloss: 8.09895e-08
# [157]	valid_0's binary_logloss: 7.32824e-08	valid_0's binary_logloss: 7.32824e-08
# [158]	valid_0's binary_logloss: 6.63086e-08	valid_0's binary_logloss: 6.63086e-08
# [159]	valid_0's binary_logloss: 5.99985e-08	valid_0's binary_logloss: 5.99985e-08
# [160]	valid_0's binary_logloss: 5.42889e-08	valid_0's binary_logloss: 5.42889e-08
# [161]	valid_0's binary_logloss: 4.91226e-08	valid_0's binary_logloss: 4.91226e-08
# [162]	valid_0's binary_logloss: 4.4448e-08	valid_0's binary_logloss: 4.4448e-08
# [163]	valid_0's binary_logloss: 4.02182e-08	valid_0's binary_logloss: 4.02182e-08
# [164]	valid_0's binary_logloss: 3.63909e-08	valid_0's binary_logloss: 3.63909e-08
# [165]	valid_0's binary_logloss: 3.29279e-08	valid_0's binary_logloss: 3.29279e-08
# [166]	valid_0's binary_logloss: 2.97944e-08	valid_0's binary_logloss: 2.97944e-08
# [167]	valid_0's binary_logloss: 2.69591e-08	valid_0's binary_logloss: 2.69591e-08
# [168]	valid_0's binary_logloss: 2.43936e-08	valid_0's binary_logloss: 2.43936e-08
# [169]	valid_0's binary_logloss: 2.20722e-08	valid_0's binary_logloss: 2.20722e-08
# [170]	valid_0's binary_logloss: 1.99718e-08	valid_0's binary_logloss: 1.99718e-08
# [171]	valid_0's binary_logloss: 1.80712e-08	valid_0's binary_logloss: 1.80712e-08
# [172]	valid_0's binary_logloss: 1.63515e-08	valid_0's binary_logloss: 1.63515e-08
# [173]	valid_0's binary_logloss: 1.47955e-08	valid_0's binary_logloss: 1.47955e-08
# [174]	valid_0's binary_logloss: 1.33875e-08	valid_0's binary_logloss: 1.33875e-08
# [175]	valid_0's binary_logloss: 1.21135e-08	valid_0's binary_logloss: 1.21135e-08
# [176]	valid_0's binary_logloss: 1.09607e-08	valid_0's binary_logloss: 1.09607e-08
# [177]	valid_0's binary_logloss: 9.91769e-09	valid_0's binary_logloss: 9.91769e-09
# [178]	valid_0's binary_logloss: 8.9739e-09	valid_0's binary_logloss: 8.9739e-09
# [179]	valid_0's binary_logloss: 8.11992e-09	valid_0's binary_logloss: 8.11992e-09
# [180]	valid_0's binary_logloss: 7.3472e-09	valid_0's binary_logloss: 7.3472e-09
# [181]	valid_0's binary_logloss: 6.64803e-09	valid_0's binary_logloss: 6.64803e-09
# [182]	valid_0's binary_logloss: 6.01538e-09	valid_0's binary_logloss: 6.01538e-09
# [183]	valid_0's binary_logloss: 5.44294e-09	valid_0's binary_logloss: 5.44294e-09
# [184]	valid_0's binary_logloss: 4.92498e-09	valid_0's binary_logloss: 4.92498e-09
# [185]	valid_0's binary_logloss: 4.4563e-09	valid_0's binary_logloss: 4.4563e-09
# [186]	valid_0's binary_logloss: 4.03223e-09	valid_0's binary_logloss: 4.03223e-09
# [187]	valid_0's binary_logloss: 3.64851e-09	valid_0's binary_logloss: 3.64851e-09
# [188]	valid_0's binary_logloss: 3.30131e-09	valid_0's binary_logloss: 3.30131e-09
# [189]	valid_0's binary_logloss: 2.98715e-09	valid_0's binary_logloss: 2.98715e-09
# [190]	valid_0's binary_logloss: 2.70289e-09	valid_0's binary_logloss: 2.70289e-09
# [191]	valid_0's binary_logloss: 2.44567e-09	valid_0's binary_logloss: 2.44567e-09
# [192]	valid_0's binary_logloss: 2.21294e-09	valid_0's binary_logloss: 2.21294e-09
# [193]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [194]	valid_0's binary_logloss: 1.8118e-09	valid_0's binary_logloss: 1.8118e-09
# [195]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# [196]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# [197]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# [198]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# [199]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# [200]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# Did not meet early stopping. Best iteration is:
# [195]	valid_0's binary_logloss: 1.63938e-09	valid_0's binary_logloss: 1.63938e-09
# LGBMClassifier(n_estimators=200, random_state=2022)

# %%
# 모델 성능을 출력해보자.
print('train score : {:.3f}'.format(lgb_model.score(X_train, y_train)))
print('test score : {:.3f}'.format(lgb_model.score(X_test, y_test)))
print('Light GBM 분류 report:\n', classification_report(y_test, lgb_model.predict(X_test)))
print(confusion_matrix(y_test, lgb_model.predict(X_test)))
# Out:
# train score : 1.000
# test score : 1.000
# Light GBM 분류 report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    245325
#            1       1.00      1.00      1.00      7414
#
#     accuracy                           1.00    252739
#    macro avg       1.00      1.00      1.00    252739
# weighted avg       1.00      1.00      1.00    252739
#
# [[245325      0]
#  [     0   7414]]

# %%
lgb_model.predict_proba(X_test)
# Out:
# array([[9.99999998e-01, 1.63938288e-09],
#        [1.63938285e-09, 9.99999998e-01],
#        [9.99999998e-01, 1.63938288e-09],
#        ...,
#        [9.99999998e-01, 1.63938288e-09],
#        [9.99999998e-01, 1.63938288e-09],
#        [9.99999998e-01, 1.63938288e-09]])

# %%
# GridSearchCV(모델, param_grid, cv, scoring, n_jobs, verbose)
param_grid = {
    'max_depth' :[50, 100, 150], 
    'learning_rate' :[0.001, 0.01, 0.1],
}

# 전처리를 거친 x_train으로 grid search cross validation 수행
gs = GridSearchCV(lgb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1, scoring = 'f1')
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(n_estimators=200, random_state=2022),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [50, 100, 150]},
#              scoring='f1', verbose=1)

# %%
# 가장 좋은 성능을 보인 파라미터 조합의 estimator을 model에 저장
model = gs.best_estimator_

# dataset 데이터를 예측 및 성능 평가
data_pred = model.predict(X_test)

# %%
print(f'optimized parameters: {model}')
# Out:
# optimized parameters: LGBMClassifier(learning_rate=0.001, max_depth=50, n_estimators=200,
#                random_state=2022)

# %%
print('test score : {:.3f}'.format(model.score(X_test, y_test)))
print('Light GBM 분류 report:\n', classification_report(y_test, data_pred))
print(confusion_matrix(y_test, data_pred))
# Out:
# test score : 1.000
# Light GBM 분류 report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    245325
#            1       1.00      1.00      1.00      7414
#
#     accuracy                           1.00    252739
#    macro avg       1.00      1.00      1.00    252739
# weighted avg       1.00      1.00      1.00    252739
#
# [[245325      0]
#  [     0   7414]]

# %%
model.predict_proba(X_test)
# Out:
# array([[0.59066875, 0.40933125],
#        [0.40933125, 0.59066875],
#        [0.59066875, 0.40933125],
#        ...,
#        [0.59066875, 0.40933125],
#        [0.59066875, 0.40933125],
#        [0.59066875, 0.40933125]])

# %%
# 특성 중요도를 시각화
fig, ax = plt.subplots(figsize = (15, 8))
plot_importance(lgb_model, ax=ax)
plt.show()

# %%
# decision tree를 시각화. 
fig, ax = plt.subplots(figsize = (15, 10))
plot_tree(lgb_model, ax=ax)

# %% [markdown]
# # 훈련/검증데이터 분리

# %%
file_name = 'final_data_v2.csv'
file_path = os.getcwd()+'/drive/MyDrive/Colab Notebooks/' 
df = pd.read_csv(file_path+file_name, encoding='utf-8')
df.rename(columns={'category_id_1':'category1'}, inplace=True)
df.head(3)
# Out:
#                  imp_id  content_id                 server_time_kst_x  \
# 0  9919612e44382421285c   162261579  2021-09-01 00:01:42.466000+09:00
# 1  9919612e444924217d59   145430389  2021-09-01 00:01:42.466000+09:00
# 2  97f9612e444d18489e0e    98827336  2021-09-01 00:01:40.339000+09:00
#
#    imp_hour  bid_price_x  click_label user_gender  user_age_group  user_age  \
# 0         0           55            0           F               1        16
# 1         0           70            0           F               2        26
# 2         0           50            0           F               5        53
#
#    user_following_cnt  user_pay_count  user_parcel_post_count  \
# 0                   3               0                       0
# 1                   0               0                       0
# 2                   0               0                       0
#
#    user_transfer_count  user_chat_count  \
# 0                    0                2
# 1                    0                0
# 2                    0                0
#
#                                       name  \
# 0        Z플립 5G  256GB  [그레이]  48082  (S급)
# 1      최저가60 무선청소기 기펠상위모델 국내브랜드 셀프스텐드 정품무배
# 2  정품 원터치텐트 낚시텐트 자외선차단텐트 방수텐트 캠핑텐트 간편 자동텐트
#
#                                          keyword     price  flag_used  \
# 0            Z플립5G,제트플립,제트플립5G,갤럭시Z플립5G,Z플립5G그레이  580000.0        1.0
# 1                          기펠청소기,무선청소기,코드제로,에어슬림  135000.0        2.0
# 2  원터치텐트간편텐트,낚시텐트등산텐트,자외선차단방수텐트,자동텐트감성캠핑,캠핑용품그늘막   26000.0        2.0
#
#    category1  emergency_cnt  comment_cnt  ad_interest  ad_pfavcnt  \
# 0        600            0.0          0.0        120.0         4.0
# 1        600            0.0          3.0       5385.0       153.0
# 2        700            0.0         12.0      29950.0       759.0
#
#    adver_favorite_count  adver_grade  adver_item_count  adver_interest  \
# 0                2063.0       7539.0             784.0          3424.0
# 1                 799.0       5520.0             433.0         16794.0
# 2                2120.0       3252.0            2053.0         32794.0
#
#    adver_review_count  adver_comment_count  adver_pay_count  \
# 0               755.0                392.0            677.0
# 1               570.0                250.0            942.0
# 2               351.0                441.0            166.0
#
#    adver_parcel_post_count  adver_transfer_count  adver_chat_count  \
# 0                      0.0                   5.0             236.0
# 1                      0.0                  57.0              11.0
# 2                      0.0                  16.0               3.0
#
#        m_time                                    content_img_url
# 0  1629443915  https://media.bunjang.co.kr/product/162261579_...
# 1  1629943339  https://media.bunjang.co.kr/product/145430389_...
# 2  1627289231  https://media.bunjang.co.kr/product/98827336_1...

# %%
cols = {'obj': [],
        'cat': [],
       'cont': []
        }

def data_split():
    file_name = 'final_data_v2.csv'
    file_path = os.getcwd()+'/drive/MyDrive/Colab Notebooks/' #[:-16]는 본인 경로에 맞게 있어도 되고 없어도 됨.
    df = pd.read_csv(file_path+file_name, encoding='utf-8')
    df.rename(columns={'category_id_1':'category1'}, inplace=True)

    # 데이터 유형별 분류하기
    for dt_idx, dt_val in zip(df.dtypes.index, df.dtypes.values):
        if dt_val == 'object':
            if ('id' in dt_idx) | ('time' in dt_idx) | ('name' in dt_idx) | ('keyword' in dt_idx) |('url' in dt_idx):
                df.drop(columns = dt_idx, axis=1, inplace=True)
            else:
                cols['obj'].append(dt_idx)

        else:
            if ('id' in dt_idx) | ('time' in dt_idx):
                df.drop(columns = dt_idx, axis=1, inplace=True)
            else:
                if len(df[dt_idx].value_counts()) <= 30: #연속형 데이터 중 30개 내의 범주로 나눌 수 있는 데이터 = category로 구분.
                    cols['cat'].append(dt_idx)
                else:
                    if ('hour' in dt_idx) | ('group' in dt_idx):
                        pass
                    else:
                        cols['cont'].append(dt_idx) 

    return cols

def reorganization(df):
  data = pd.DataFrame()
  cols = data_split()
  for k, v in cols.items():
    if k == 'obj':
      data = pd.concat([data, df[v]], axis=1)
    elif k == 'cont':
      data = pd.concat([data, df[v]], axis=1)
    else:
      data = pd.concat([data, df[v]], axis=1)

  return data

# %%
data = reorganization(df)
data.columns
# Out:
# Index(['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used',
#        'category1', 'emergency_cnt', 'user_age', 'user_following_cnt',
#        'user_pay_count', 'user_parcel_post_count', 'user_transfer_count',
#        'user_chat_count', 'price', 'comment_cnt', 'ad_interest', 'ad_pfavcnt',
#        'adver_favorite_count', 'adver_grade', 'adver_item_count',
#        'adver_interest', 'adver_review_count', 'adver_comment_count',
#        'adver_pay_count', 'adver_parcel_post_count', 'adver_transfer_count',
#        'adver_chat_count'],
#       dtype='object')

# %%
data.head(3)
# Out:
#   user_gender  imp_hour  click_label  user_age_group  flag_used  category1  \
# 0           F         0            0               1        1.0        600
# 1           F         0            0               2        2.0        600
# 2           F         0            0               5        2.0        700
#
#    emergency_cnt  user_age  user_following_cnt  user_pay_count  \
# 0            0.0        16                   3               0
# 1            0.0        26                   0               0
# 2            0.0        53                   0               0
#
#    user_parcel_post_count  user_transfer_count  user_chat_count     price  \
# 0                       0                    0                2  580000.0
# 1                       0                    0                0  135000.0
# 2                       0                    0                0   26000.0
#
#    comment_cnt  ad_interest  ad_pfavcnt  adver_favorite_count  adver_grade  \
# 0          0.0        120.0         4.0                2063.0       7539.0
# 1          3.0       5385.0       153.0                 799.0       5520.0
# 2         12.0      29950.0       759.0                2120.0       3252.0
#
#    adver_item_count  adver_interest  adver_review_count  adver_comment_count  \
# 0             784.0          3424.0               755.0                392.0
# 1             433.0         16794.0               570.0                250.0
# 2            2053.0         32794.0               351.0                441.0
#
#    adver_pay_count  adver_parcel_post_count  adver_transfer_count  \
# 0            677.0                      0.0                   5.0
# 1            942.0                      0.0                  57.0
# 2            166.0                      0.0                  16.0
#
#    adver_chat_count
# 0             236.0
# 1              11.0
# 2               3.0

# %%
def preprocessing(df):
    # 데이터 유형별 분류하기
    modified_df = pd.DataFrame()

    for i, c in enumerate(df.columns): 
        if (c in cols['obj']) | (c in cols['cat']): 
          if 'click' in c:    # click_label 컬럼 = y 변수로 사용 (그대로 두기)
                modified_df = pd.concat([modified_df, df[c]], axis=1)
          else:
            dummied_data = LabelEncoder().fit_transform(df[[c]])
            dummied_data = pd.DataFrame(dummied_data, columns = [c])
            modified_df = pd.concat([modified_df, dummied_data], axis=1)

        else:
            scaled_num_data = RobustScaler().fit_transform(df[[c]])
            scaled_num_data = pd.DataFrame(scaled_num_data, columns = [c])
            modified_df = pd.concat([modified_df,scaled_num_data], axis=1)

    print('---- Data info ----')
    print(f'Modified DF columns: {modified_df.columns.to_list()}')
    print(f'# of Modified DF columns: {modified_df.shape[1]}')
    print(f'DataFrame has no null?', end = ' ')
    if df.isnull().sum().count() == df.shape[1]:
      print('Yes')
    else:
      print('No')
    return modified_df

# %%
df = preprocessing(data)
df.head(3)
# Out:
# ---- Data info ----
# Modified DF columns: ['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used', 'category1', 'emergency_cnt', 'user_age', 'user_following_cnt', 'user_pay_count', 'user_parcel_post_count', 'user_transfer_count', 'user_chat_count', 'price', 'comment_cnt', 'ad_interest', 'ad_pfavcnt', 'adver_favorite_count', 'adver_grade', 'adver_item_count', 'adver_interest', 'adver_review_count', 'adver_comment_count', 'adver_pay_count', 'adver_parcel_post_count', 'adver_transfer_count', 'adver_chat_count']
# # of Modified DF columns: 27
# DataFrame has no null? Yes
#    user_gender  imp_hour  click_label  user_age_group  flag_used  category1  \
# 0            0         0            0               0          0         10
# 1            0         0            0               1          1         10
# 2            0         0            0               4          1         11
#
#    emergency_cnt  user_age  user_following_cnt  user_pay_count  \
# 0              0 -0.904762                 0.4             0.0
# 1              0 -0.428571                -0.2             0.0
# 2              0  0.857143                -0.2             0.0
#
#    user_parcel_post_count  user_transfer_count  user_chat_count     price  \
# 0                     0.0                  0.0              2.0  0.442373
# 1                     0.0                  0.0              0.0 -0.311864
# 2                     0.0                  0.0              0.0 -0.496610
#
#    comment_cnt  ad_interest  ad_pfavcnt  adver_favorite_count  adver_grade  \
# 0          0.0    -0.138204   -0.190476              0.541252     0.731446
# 1          3.0     0.607335    1.228571             -0.086978     0.442728
# 2         12.0     4.085811    7.000000              0.569583     0.118404
#
#    adver_item_count  adver_interest  adver_review_count  adver_comment_count  \
# 0          0.742301       -0.030500            0.695833             0.246594
# 1          0.173420        0.339880            0.438889             0.053134
# 2          2.799028        0.783118            0.134722             0.313351
#
#    adver_pay_count  adver_parcel_post_count  adver_transfer_count  \
# 0         1.209776                      0.0              0.714286
# 1         1.749491                      0.0              8.142857
# 2         0.169043                      0.0              2.285714
#
#    adver_chat_count
# 0         17.769231
# 1          0.461538
# 2         -0.153846

# %%
X = df
y = df['click_label']

print(f"X features' name (10): {X.columns.to_list()[:10]}")
print(f"y feature's name: {y.name}")
print()

## create train and test datasets (7:3 ratio)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2022, stratify = y) #y 비율에 따른 층화추출 및 데이터를 7:3의 비율로 나누기

print(f"# of train_data's rows: {X_train.shape[0]} \n# of test_data's rows: {X_test.shape[0]}")
print()
print(f'train:test ratio = {round(X_train.shape[0]/(X_train.shape[0]+ X_test.shape[0]),2)}:{round(X_test.shape[0]/(X_train.shape[0]+ X_test.shape[0]), 2)}')

oversample = SMOTE(random_state=2022) # 불균형 데이터 셋인 번개장터 데이터 셋 불균형 문제 완화
X_train, y_train = oversample.fit_resample(X_train, y_train)

print("data's shape (x -> y & train -> test): ", (X_train.shape, y_train.shape, X_test.shape, y_train.shape))
print()

## create train and validation datasets (8:2 ratio)
x_train, x_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state = 2022, stratify = y_train)

print(f"# of train_data's rows: {x_train.shape[0]} \n# of validation_data's rows: {x_val.shape[0]}")
print()
print(f'train:test ratio = {round(x_train.shape[0]/(x_train.shape[0]+ x_val.shape[0]),2)}:{round(x_val.shape[0]/(x_train.shape[0]+ x_val.shape[0]), 2)}')
print("data's shape (x -> y & train -> test): ", (x_train.shape, y_train.shape, x_val.shape, y_val.shape))
print()
# Out:
# X features' name (10): ['user_gender', 'imp_hour', 'click_label', 'user_age_group', 'flag_used', 'category1', 'emergency_cnt', 'user_age', 'user_following_cnt', 'user_pay_count']
# y feature's name: click_label
#
# # of train_data's rows: 589724
# # of test_data's rows: 252739
#
# train:test ratio = 0.7:0.3
# data's shape (x -> y & train -> test):  ((1144850, 27), (1144850,), (252739, 27), (1144850,))
#
# # of train_data's rows: 915880
# # of validation_data's rows: 228970
#
# train:test ratio = 0.8:0.2
# data's shape (x -> y & train -> test):  ((915880, 27), (915880,), (228970, 27), (228970,))

# %%
lgb_model = lgb.LGBMClassifier(random_state=2022, boosting_type = 'gbdt', n_estimators = 200)
lgb_model = lgb_model.fit(x_train, y_train, early_stopping_rounds=10, eval_metric="logloss", eval_set = [(x_val, y_val)])
lgb_model
# Out:
# [1]	valid_0's binary_logloss: 0.598139	valid_0's binary_logloss: 0.598139
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.520329	valid_0's binary_logloss: 0.520329
# [3]	valid_0's binary_logloss: 0.455444	valid_0's binary_logloss: 0.455444
# [4]	valid_0's binary_logloss: 0.400598	valid_0's binary_logloss: 0.400598
# [5]	valid_0's binary_logloss: 0.353747	valid_0's binary_logloss: 0.353747
# [6]	valid_0's binary_logloss: 0.313388	valid_0's binary_logloss: 0.313388
# [7]	valid_0's binary_logloss: 0.278384	valid_0's binary_logloss: 0.278384
# [8]	valid_0's binary_logloss: 0.247853	valid_0's binary_logloss: 0.247853
# [9]	valid_0's binary_logloss: 0.221099	valid_0's binary_logloss: 0.221099
# [10]	valid_0's binary_logloss: 0.19756	valid_0's binary_logloss: 0.19756
# [11]	valid_0's binary_logloss: 0.176781	valid_0's binary_logloss: 0.176781
# [12]	valid_0's binary_logloss: 0.158385	valid_0's binary_logloss: 0.158385
# [13]	valid_0's binary_logloss: 0.142058	valid_0's binary_logloss: 0.142058
# [14]	valid_0's binary_logloss: 0.127536	valid_0's binary_logloss: 0.127536
# [15]	valid_0's binary_logloss: 0.114594	valid_0's binary_logloss: 0.114594
# [16]	valid_0's binary_logloss: 0.103042	valid_0's binary_logloss: 0.103042
# [17]	valid_0's binary_logloss: 0.0927149	valid_0's binary_logloss: 0.0927149
# [18]	valid_0's binary_logloss: 0.0834714	valid_0's binary_logloss: 0.0834714
# [19]	valid_0's binary_logloss: 0.0751883	valid_0's binary_logloss: 0.0751883
# [20]	valid_0's binary_logloss: 0.0677582	valid_0's binary_logloss: 0.0677582
# [21]	valid_0's binary_logloss: 0.0610874	valid_0's binary_logloss: 0.0610874
# [22]	valid_0's binary_logloss: 0.0550936	valid_0's binary_logloss: 0.0550936
# [23]	valid_0's binary_logloss: 0.0497041	valid_0's binary_logloss: 0.0497041
# [24]	valid_0's binary_logloss: 0.044855	valid_0's binary_logloss: 0.044855
# [25]	valid_0's binary_logloss: 0.0404896	valid_0's binary_logloss: 0.0404896
# [26]	valid_0's binary_logloss: 0.0365577	valid_0's binary_logloss: 0.0365577
# [27]	valid_0's binary_logloss: 0.0330146	valid_0's binary_logloss: 0.0330146
# [28]	valid_0's binary_logloss: 0.0298206	valid_0's binary_logloss: 0.0298206
# [29]	valid_0's binary_logloss: 0.0269402	valid_0's binary_logloss: 0.0269402
# [30]	valid_0's binary_logloss: 0.0243418	valid_0's binary_logloss: 0.0243418
# [31]	valid_0's binary_logloss: 0.021997	valid_0's binary_logloss: 0.021997
# [32]	valid_0's binary_logloss: 0.0198806	valid_0's binary_logloss: 0.0198806
# [33]	valid_0's binary_logloss: 0.0179698	valid_0's binary_logloss: 0.0179698
# [34]	valid_0's binary_logloss: 0.0162444	valid_0's binary_logloss: 0.0162444
# [35]	valid_0's binary_logloss: 0.0146859	valid_0's binary_logloss: 0.0146859
# [36]	valid_0's binary_logloss: 0.0132781	valid_0's binary_logloss: 0.0132781
# [37]	valid_0's binary_logloss: 0.0120061	valid_0's binary_logloss: 0.0120061
# [38]	valid_0's binary_logloss: 0.0108567	valid_0's binary_logloss: 0.0108567
# [39]	valid_0's binary_logloss: 0.00981796	valid_0's binary_logloss: 0.00981796
# [40]	valid_0's binary_logloss: 0.00887907	valid_0's binary_logloss: 0.00887907
# [41]	valid_0's binary_logloss: 0.00803037	valid_0's binary_logloss: 0.00803037
# [42]	valid_0's binary_logloss: 0.00726311	valid_0's binary_logloss: 0.00726311
# [43]	valid_0's binary_logloss: 0.00656942	valid_0's binary_logloss: 0.00656942
# [44]	valid_0's binary_logloss: 0.00594221	valid_0's binary_logloss: 0.00594221
# [45]	valid_0's binary_logloss: 0.00537506	valid_0's binary_logloss: 0.00537506
# [46]	valid_0's binary_logloss: 0.00486218	valid_0's binary_logloss: 0.00486218
# [47]	valid_0's binary_logloss: 0.00439836	valid_0's binary_logloss: 0.00439836
# [48]	valid_0's binary_logloss: 0.00397888	valid_0's binary_logloss: 0.00397888
# [49]	valid_0's binary_logloss: 0.00359949	valid_0's binary_logloss: 0.00359949
# [50]	valid_0's binary_logloss: 0.00325634	valid_0's binary_logloss: 0.00325634
# [51]	valid_0's binary_logloss: 0.00294595	valid_0's binary_logloss: 0.00294595
# [52]	valid_0's binary_logloss: 0.00266519	valid_0's binary_logloss: 0.00266519
# [53]	valid_0's binary_logloss: 0.00241123	valid_0's binary_logloss: 0.00241123
# [54]	valid_0's binary_logloss: 0.0021815	valid_0's binary_logloss: 0.0021815
# [55]	valid_0's binary_logloss: 0.00197367	valid_0's binary_logloss: 0.00197367
# [56]	valid_0's binary_logloss: 0.00178567	valid_0's binary_logloss: 0.00178567
# [57]	valid_0's binary_logloss: 0.00161559	valid_0's binary_logloss: 0.00161559
# [58]	valid_0's binary_logloss: 0.00146172	valid_0's binary_logloss: 0.00146172
# [59]	valid_0's binary_logloss: 0.00132252	valid_0's binary_logloss: 0.00132252
# [60]	valid_0's binary_logloss: 0.00119658	valid_0's binary_logloss: 0.00119658
# [61]	valid_0's binary_logloss: 0.00108264	valid_0's binary_logloss: 0.00108264
# [62]	valid_0's binary_logloss: 0.000979561	valid_0's binary_logloss: 0.000979561
# [63]	valid_0's binary_logloss: 0.000886298	valid_0's binary_logloss: 0.000886298
# [64]	valid_0's binary_logloss: 0.000801918	valid_0's binary_logloss: 0.000801918
# [65]	valid_0's binary_logloss: 0.000725575	valid_0's binary_logloss: 0.000725575
# [66]	valid_0's binary_logloss: 0.000656502	valid_0's binary_logloss: 0.000656502
# [67]	valid_0's binary_logloss: 0.000594007	valid_0's binary_logloss: 0.000594007
# [68]	valid_0's binary_logloss: 0.000537463	valid_0's binary_logloss: 0.000537463
# [69]	valid_0's binary_logloss: 0.000486303	valid_0's binary_logloss: 0.000486303
# [70]	valid_0's binary_logloss: 0.000440014	valid_0's binary_logloss: 0.000440014
# [71]	valid_0's binary_logloss: 0.000398132	valid_0's binary_logloss: 0.000398132
# [72]	valid_0's binary_logloss: 0.000360237	valid_0's binary_logloss: 0.000360237
# [73]	valid_0's binary_logloss: 0.00032595	valid_0's binary_logloss: 0.00032595
# [74]	valid_0's binary_logloss: 0.000294927	valid_0's binary_logloss: 0.000294927
# [75]	valid_0's binary_logloss: 0.000266857	valid_0's binary_logloss: 0.000266857
# [76]	valid_0's binary_logloss: 0.000241458	valid_0's binary_logloss: 0.000241458
# [77]	valid_0's binary_logloss: 0.000218478	valid_0's binary_logloss: 0.000218478
# [78]	valid_0's binary_logloss: 0.000197685	valid_0's binary_logloss: 0.000197685
# [79]	valid_0's binary_logloss: 0.000178871	valid_0's binary_logloss: 0.000178871
# [80]	valid_0's binary_logloss: 0.000161847	valid_0's binary_logloss: 0.000161847
# [81]	valid_0's binary_logloss: 0.000146444	valid_0's binary_logloss: 0.000146444
# [82]	valid_0's binary_logloss: 0.000132507	valid_0's binary_logloss: 0.000132507
# [83]	valid_0's binary_logloss: 0.000119897	valid_0's binary_logloss: 0.000119897
# [84]	valid_0's binary_logloss: 0.000108486	valid_0's binary_logloss: 0.000108486
# [85]	valid_0's binary_logloss: 9.81619e-05	valid_0's binary_logloss: 9.81619e-05
# [86]	valid_0's binary_logloss: 8.88201e-05	valid_0's binary_logloss: 8.88201e-05
# [87]	valid_0's binary_logloss: 8.03674e-05	valid_0's binary_logloss: 8.03674e-05
# [88]	valid_0's binary_logloss: 7.27191e-05	valid_0's binary_logloss: 7.27191e-05
# [89]	valid_0's binary_logloss: 6.57987e-05	valid_0's binary_logloss: 6.57987e-05
# [90]	valid_0's binary_logloss: 5.9537e-05	valid_0's binary_logloss: 5.9537e-05
# [91]	valid_0's binary_logloss: 5.38711e-05	valid_0's binary_logloss: 5.38711e-05
# [92]	valid_0's binary_logloss: 4.87445e-05	valid_0's binary_logloss: 4.87445e-05
# [93]	valid_0's binary_logloss: 4.41057e-05	valid_0's binary_logloss: 4.41057e-05
# [94]	valid_0's binary_logloss: 3.99084e-05	valid_0's binary_logloss: 3.99084e-05
# [95]	valid_0's binary_logloss: 3.61105e-05	valid_0's binary_logloss: 3.61105e-05
# [96]	valid_0's binary_logloss: 3.26741e-05	valid_0's binary_logloss: 3.26741e-05
# [97]	valid_0's binary_logloss: 2.95647e-05	valid_0's binary_logloss: 2.95647e-05
# [98]	valid_0's binary_logloss: 2.67512e-05	valid_0's binary_logloss: 2.67512e-05
# [99]	valid_0's binary_logloss: 2.42055e-05	valid_0's binary_logloss: 2.42055e-05
# [100]	valid_0's binary_logloss: 2.1902e-05	valid_0's binary_logloss: 2.1902e-05
# [101]	valid_0's binary_logloss: 1.98177e-05	valid_0's binary_logloss: 1.98177e-05
# [102]	valid_0's binary_logloss: 1.79318e-05	valid_0's binary_logloss: 1.79318e-05
# [103]	valid_0's binary_logloss: 1.62253e-05	valid_0's binary_logloss: 1.62253e-05
# [104]	valid_0's binary_logloss: 1.46813e-05	valid_0's binary_logloss: 1.46813e-05
# [105]	valid_0's binary_logloss: 1.32842e-05	valid_0's binary_logloss: 1.32842e-05
# [106]	valid_0's binary_logloss: 1.202e-05	valid_0's binary_logloss: 1.202e-05
# [107]	valid_0's binary_logloss: 1.08761e-05	valid_0's binary_logloss: 1.08761e-05
# [108]	valid_0's binary_logloss: 9.84112e-06	valid_0's binary_logloss: 9.84112e-06
# [109]	valid_0's binary_logloss: 8.90461e-06	valid_0's binary_logloss: 8.90461e-06
# [110]	valid_0's binary_logloss: 8.05722e-06	valid_0's binary_logloss: 8.05722e-06
# [111]	valid_0's binary_logloss: 7.29047e-06	valid_0's binary_logloss: 7.29047e-06
# [112]	valid_0's binary_logloss: 6.59669e-06	valid_0's binary_logloss: 6.59669e-06
# [113]	valid_0's binary_logloss: 5.96893e-06	valid_0's binary_logloss: 5.96893e-06
# [114]	valid_0's binary_logloss: 5.40091e-06	valid_0's binary_logloss: 5.40091e-06
# [115]	valid_0's binary_logloss: 4.88694e-06	valid_0's binary_logloss: 4.88694e-06
# [116]	valid_0's binary_logloss: 4.42189e-06	valid_0's binary_logloss: 4.42189e-06
# [117]	valid_0's binary_logloss: 4.00109e-06	valid_0's binary_logloss: 4.00109e-06
# [118]	valid_0's binary_logloss: 3.62033e-06	valid_0's binary_logloss: 3.62033e-06
# [119]	valid_0's binary_logloss: 3.27581e-06	valid_0's binary_logloss: 3.27581e-06
# [120]	valid_0's binary_logloss: 2.96408e-06	valid_0's binary_logloss: 2.96408e-06
# [121]	valid_0's binary_logloss: 2.68201e-06	valid_0's binary_logloss: 2.68201e-06
# [122]	valid_0's binary_logloss: 2.42678e-06	valid_0's binary_logloss: 2.42678e-06
# [123]	valid_0's binary_logloss: 2.19584e-06	valid_0's binary_logloss: 2.19584e-06
# [124]	valid_0's binary_logloss: 1.98688e-06	valid_0's binary_logloss: 1.98688e-06
# [125]	valid_0's binary_logloss: 1.7978e-06	valid_0's binary_logloss: 1.7978e-06
# [126]	valid_0's binary_logloss: 1.62672e-06	valid_0's binary_logloss: 1.62672e-06
# [127]	valid_0's binary_logloss: 1.47192e-06	valid_0's binary_logloss: 1.47192e-06
# [128]	valid_0's binary_logloss: 1.33185e-06	valid_0's binary_logloss: 1.33185e-06
# [129]	valid_0's binary_logloss: 1.2051e-06	valid_0's binary_logloss: 1.2051e-06
# [130]	valid_0's binary_logloss: 1.09042e-06	valid_0's binary_logloss: 1.09042e-06
# [131]	valid_0's binary_logloss: 9.86655e-07	valid_0's binary_logloss: 9.86655e-07
# [132]	valid_0's binary_logloss: 8.92762e-07	valid_0's binary_logloss: 8.92762e-07
# [133]	valid_0's binary_logloss: 8.07805e-07	valid_0's binary_logloss: 8.07805e-07
# [134]	valid_0's binary_logloss: 7.30932e-07	valid_0's binary_logloss: 7.30932e-07
# [135]	valid_0's binary_logloss: 6.61374e-07	valid_0's binary_logloss: 6.61374e-07
# [136]	valid_0's binary_logloss: 5.98436e-07	valid_0's binary_logloss: 5.98436e-07
# [137]	valid_0's binary_logloss: 5.41488e-07	valid_0's binary_logloss: 5.41488e-07
# [138]	valid_0's binary_logloss: 4.89958e-07	valid_0's binary_logloss: 4.89958e-07
# [139]	valid_0's binary_logloss: 4.43333e-07	valid_0's binary_logloss: 4.43333e-07
# [140]	valid_0's binary_logloss: 4.01144e-07	valid_0's binary_logloss: 4.01144e-07
# [141]	valid_0's binary_logloss: 3.6297e-07	valid_0's binary_logloss: 3.6297e-07
# [142]	valid_0's binary_logloss: 3.28429e-07	valid_0's binary_logloss: 3.28429e-07
# [143]	valid_0's binary_logloss: 2.97175e-07	valid_0's binary_logloss: 2.97175e-07
# [144]	valid_0's binary_logloss: 2.68895e-07	valid_0's binary_logloss: 2.68895e-07
# [145]	valid_0's binary_logloss: 2.43306e-07	valid_0's binary_logloss: 2.43306e-07
# [146]	valid_0's binary_logloss: 2.20152e-07	valid_0's binary_logloss: 2.20152e-07
# [147]	valid_0's binary_logloss: 1.99202e-07	valid_0's binary_logloss: 1.99202e-07
# [148]	valid_0's binary_logloss: 1.80246e-07	valid_0's binary_logloss: 1.80246e-07
# [149]	valid_0's binary_logloss: 1.63093e-07	valid_0's binary_logloss: 1.63093e-07
# [150]	valid_0's binary_logloss: 1.47573e-07	valid_0's binary_logloss: 1.47573e-07
# [151]	valid_0's binary_logloss: 1.33529e-07	valid_0's binary_logloss: 1.33529e-07
# [152]	valid_0's binary_logloss: 1.20822e-07	valid_0's binary_logloss: 1.20822e-07
# [153]	valid_0's binary_logloss: 1.09324e-07	valid_0's binary_logloss: 1.09324e-07
# [154]	valid_0's binary_logloss: 9.89208e-08	valid_0's binary_logloss: 9.89208e-08
# [155]	valid_0's binary_logloss: 8.95073e-08	valid_0's binary_logloss: 8.95073e-08
# [156]	valid_0's binary_logloss: 8.09895e-08	valid_0's binary_logloss: 8.09895e-08
# [157]	valid_0's binary_logloss: 7.32824e-08	valid_0's binary_logloss: 7.32824e-08
# [158]	valid_0's binary_logloss: 6.63086e-08	valid_0's binary_logloss: 6.63086e-08
# [159]	valid_0's binary_logloss: 5.99985e-08	valid_0's binary_logloss: 5.99985e-08
# [160]	valid_0's binary_logloss: 5.42889e-08	valid_0's binary_logloss: 5.42889e-08
# [161]	valid_0's binary_logloss: 4.91226e-08	valid_0's binary_logloss: 4.91226e-08
# [162]	valid_0's binary_logloss: 4.4448e-08	valid_0's binary_logloss: 4.4448e-08
# [163]	valid_0's binary_logloss: 4.02182e-08	valid_0's binary_logloss: 4.02182e-08
# [164]	valid_0's binary_logloss: 3.63909e-08	valid_0's binary_logloss: 3.63909e-08
# [165]	valid_0's binary_logloss: 3.29279e-08	valid_0's binary_logloss: 3.29279e-08
# [166]	valid_0's binary_logloss: 2.97944e-08	valid_0's binary_logloss: 2.97944e-08
# [167]	valid_0's binary_logloss: 2.69591e-08	valid_0's binary_logloss: 2.69591e-08
# [168]	valid_0's binary_logloss: 2.43936e-08	valid_0's binary_logloss: 2.43936e-08
# [169]	valid_0's binary_logloss: 2.20722e-08	valid_0's binary_logloss: 2.20722e-08
# [170]	valid_0's binary_logloss: 1.99718e-08	valid_0's binary_logloss: 1.99718e-08
# [171]	valid_0's binary_logloss: 1.80712e-08	valid_0's binary_logloss: 1.80712e-08
# [172]	valid_0's binary_logloss: 1.63515e-08	valid_0's binary_logloss: 1.63515e-08
# [173]	valid_0's binary_logloss: 1.47955e-08	valid_0's binary_logloss: 1.47955e-08
# [174]	valid_0's binary_logloss: 1.33875e-08	valid_0's binary_logloss: 1.33875e-08
# [175]	valid_0's binary_logloss: 1.21135e-08	valid_0's binary_logloss: 1.21135e-08
# [176]	valid_0's binary_logloss: 1.09607e-08	valid_0's binary_logloss: 1.09607e-08
# [177]	valid_0's binary_logloss: 9.91769e-09	valid_0's binary_logloss: 9.91769e-09
# [178]	valid_0's binary_logloss: 8.9739e-09	valid_0's binary_logloss: 8.9739e-09
# [179]	valid_0's binary_logloss: 8.11992e-09	valid_0's binary_logloss: 8.11992e-09
# [180]	valid_0's binary_logloss: 7.3472e-09	valid_0's binary_logloss: 7.3472e-09
# [181]	valid_0's binary_logloss: 6.64803e-09	valid_0's binary_logloss: 6.64803e-09
# [182]	valid_0's binary_logloss: 6.01538e-09	valid_0's binary_logloss: 6.01538e-09
# [183]	valid_0's binary_logloss: 5.44294e-09	valid_0's binary_logloss: 5.44294e-09
# [184]	valid_0's binary_logloss: 4.92498e-09	valid_0's binary_logloss: 4.92498e-09
# [185]	valid_0's binary_logloss: 4.4563e-09	valid_0's binary_logloss: 4.4563e-09
# [186]	valid_0's binary_logloss: 4.03223e-09	valid_0's binary_logloss: 4.03223e-09
# [187]	valid_0's binary_logloss: 3.64851e-09	valid_0's binary_logloss: 3.64851e-09
# [188]	valid_0's binary_logloss: 3.30131e-09	valid_0's binary_logloss: 3.30131e-09
# [189]	valid_0's binary_logloss: 2.98715e-09	valid_0's binary_logloss: 2.98715e-09
# [190]	valid_0's binary_logloss: 2.70289e-09	valid_0's binary_logloss: 2.70289e-09
# [191]	valid_0's binary_logloss: 2.44567e-09	valid_0's binary_logloss: 2.44567e-09
# [192]	valid_0's binary_logloss: 2.21294e-09	valid_0's binary_logloss: 2.21294e-09
# [193]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [194]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [195]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [196]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [197]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [198]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [199]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# [200]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# Did not meet early stopping. Best iteration is:
# [193]	valid_0's binary_logloss: 2.00235e-09	valid_0's binary_logloss: 2.00235e-09
# LGBMClassifier(n_estimators=200, random_state=2022)

# %%
# 모델 성능을 출력해보자.
print('train score : {:.3f}'.format(lgb_model.score(x_train, y_train)))
print('validation score : {:.3f}'.format(lgb_model.score(x_val, y_val)))
print('Light GBM 분류 report:\n', classification_report(y_val, lgb_model.predict(x_val)))
print(confusion_matrix(y_val, lgb_model.predict(x_val)))
# Out:
# train score : 1.000
# validation score : 1.000
# Light GBM 분류 report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    114485
#            1       1.00      1.00      1.00    114485
#
#     accuracy                           1.00    228970
#    macro avg       1.00      1.00      1.00    228970
# weighted avg       1.00      1.00      1.00    228970
#
# [[114485      0]
#  [     0 114485]]

# %%
lgb_model.predict_proba(x_val)
# Out:
# array([[2.00234673e-09, 9.99999998e-01],
#        [2.00234673e-09, 9.99999998e-01],
#        [2.00234673e-09, 9.99999998e-01],
#        ...,
#        [2.00234673e-09, 9.99999998e-01],
#        [9.99999998e-01, 2.00234677e-09],
#        [9.99999998e-01, 2.00234677e-09]])

# %%
# GridSearchCV(모델, param_grid, cv, scoring, n_jobs, verbose)
param_grid = {
    'max_depth' :[50, 100, 150], 
    'learning_rate' :[0.001, 0.01, 0.1],
}

# 전처리를 거친 x_train으로 grid search cross validation 수행
gs = GridSearchCV(lgb_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1, scoring = 'f1')
gs.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(n_estimators=200, random_state=2022),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [50, 100, 150]},
#              scoring='f1', verbose=1)

# %%
# 가장 좋은 성능을 보인 파라미터 조합의 estimator을 model에 저장
model = gs.best_estimator_

# dataset 데이터를 예측 및 성능 평가
data_pred = model.predict(x_val)

# %%
print(f'optimized parameters: {model}')
# Out:
# optimized parameters: LGBMClassifier(learning_rate=0.001, max_depth=50, n_estimators=200,
#                random_state=2022)

# %%
print('validation score : {:.3f}'.format(model.score(x_val, y_val)))
print('Light GBM 분류 report:\n', classification_report(y_val, data_pred))
print(confusion_matrix(y_val, data_pred))
# Out:
# validation score : 1.000
# Light GBM 분류 report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    114485
#            1       1.00      1.00      1.00    114485
#
#     accuracy                           1.00    228970
#    macro avg       1.00      1.00      1.00    228970
# weighted avg       1.00      1.00      1.00    228970
#
# [[114485      0]
#  [     0 114485]]

# %%
model.predict_proba(x_val)
# Out:
# array([[0.40933125, 0.59066875],
#        [0.40933125, 0.59066875],
#        [0.40933125, 0.59066875],
#        ...,
#        [0.40933125, 0.59066875],
#        [0.59066875, 0.40933125],
#        [0.59066875, 0.40933125]])

# %%
# 특성 중요도를 시각화
fig, ax = plt.subplots(figsize = (15, 8))
plot_importance(model, ax=ax)
plt.show()

# %%
# decision tree를 시각화. 
fig, ax = plt.subplots(figsize = (15, 10))
plot_tree(model, ax=ax)
